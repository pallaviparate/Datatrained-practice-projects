# %% [markdown]
# # The World Happiness Report Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("happiness_score_dataset.csv")
df.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
print("There are {:,} rows ".format(df.shape[0]) + "and {} columns in our data".format(df.shape[1]))
# Out:
# There are 158 rows and 12 columns in our data

# %%
df.set_index('Country', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, Switzerland to Togo
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Region                         158 non-null    object
#  1   Happiness Rank                 158 non-null    int64
#  2   Happiness Score                158 non-null    float64
#  3   Standard Error                 158 non-null    float64
#  4   Economy (GDP per Capita)       158 non-null    float64
#  5   Family                         158 non-null    float64
#  6   Health (Life Expectancy)       158 non-null    float64
#  7   Freedom                        158 non-null    float64
#  8   Trust (Government Corruption)  158 non-null    float64
#  9   Generosity                     158 non-null    float64
#  10  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 14.8+ KB

# %%
df.isnull().sum()
# Out:
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.sort_values(by="Happiness Rank", ascending=True).head(10)
# Out:
#                                 Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland             Western Europe               1            7.587
# Iceland                 Western Europe               2            7.561
# Denmark                 Western Europe               3            7.527
# Norway                  Western Europe               4            7.522
# Canada                   North America               5            7.427
# Finland                 Western Europe               6            7.406
# Netherlands             Western Europe               7            7.378
# Sweden                  Western Europe               8            7.364
# New Zealand  Australia and New Zealand               9            7.286
# Australia    Australia and New Zealand              10            7.284
#
#              Standard Error  Economy (GDP per Capita)   Family  \
# Country
# Switzerland         0.03411                   1.39651  1.34951
# ...

# %%
df.sort_values(by="Happiness Rank", ascending=False).head(10)
# Out:
#                                        Region  Happiness Rank  \
# Country
# Togo                       Sub-Saharan Africa             158
# Burundi                    Sub-Saharan Africa             157
# Syria         Middle East and Northern Africa             156
# Benin                      Sub-Saharan Africa             155
# Rwanda                     Sub-Saharan Africa             154
# Afghanistan                     Southern Asia             153
# Burkina Faso               Sub-Saharan Africa             152
# Ivory Coast                Sub-Saharan Africa             151
# Guinea                     Sub-Saharan Africa             150
# Chad                       Sub-Saharan Africa             149
#
#               Happiness Score  Standard Error  Economy (GDP per Capita)  \
# Country
# Togo                    2.839         0.06727                   0.20868
# Burundi                 2.905         0.08658                   0.01530
# ...

# %% [markdown]
# # Indexing and grouping

# %%
df_Region = df.groupby('Region')

# %%
df_Region['Happiness Score'].describe().sort_values(by="mean",ascending=True).head(10)
# Out:
#                                  count      mean       std    min      25%  \
# Region
# Sub-Saharan Africa                40.0  4.202800  0.609557  2.839  3.75600
# Southern Asia                      7.0  4.580857  0.570526  3.575  4.39250
# Southeastern Asia                  9.0  5.317444  0.950020  3.819  4.87600
# Central and Eastern Europe        29.0  5.332931  0.570446  4.218  4.95900
# Middle East and Northern Africa   20.0  5.406900  1.101382  3.006  4.70775
# Eastern Asia                       6.0  5.626167  0.554053  4.874  5.22350
# Latin America and Caribbean       22.0  6.144682  0.728560  4.518  5.84050
# Western Europe                    21.0  6.689619  0.824582  4.857  6.30200
# North America                      2.0  7.273000  0.217789  7.119  7.19600
# Australia and New Zealand          2.0  7.285000  0.001414  7.284  7.28450
#
#                                    50%      75%    max
# Region
# Sub-Saharan Africa               4.272  4.58075  5.477
# ...

# %%
df[df["Region"]=="Sub-Saharan Africa"].head()
# Out:
#                                Region  Happiness Rank  Happiness Score  \
# Country
# Mauritius          Sub-Saharan Africa              71            5.477
# Nigeria            Sub-Saharan Africa              78            5.268
# Zambia             Sub-Saharan Africa              85            5.129
# Somaliland region  Sub-Saharan Africa              91            5.057
# Mozambique         Sub-Saharan Africa              94            4.971
#
#                    Standard Error  Economy (GDP per Capita)   Family  \
# Country
# Mauritius                 0.07197                   1.00761  0.98521
# Nigeria                   0.04192                   0.65435  0.90432
# Zambia                    0.06988                   0.47038  0.91612
# Somaliland region         0.06161                   0.18847  0.95152
# Mozambique                0.07896                   0.08308  1.02626
#
#                    Health (Life Expectancy)  Freedom  \
# Country
# ...

# %%
df = df.replace('Sub-Saharan Africa', 'Middle East and Northern Africa')

# %%
df_Region['Happiness Score'].describe().sort_values(by="mean",ascending=False).head(6)
# Out:
#                                  count      mean       std    min      25%  \
# Region
# Australia and New Zealand          2.0  7.285000  0.001414  7.284  7.28450
# North America                      2.0  7.273000  0.217789  7.119  7.19600
# Western Europe                    21.0  6.689619  0.824582  4.857  6.30200
# Latin America and Caribbean       22.0  6.144682  0.728560  4.518  5.84050
# Eastern Asia                       6.0  5.626167  0.554053  4.874  5.22350
# Middle East and Northern Africa   20.0  5.406900  1.101382  3.006  4.70775
#
#                                    50%      75%    max
# Region
# Australia and New Zealand        7.285  7.28550  7.286
# North America                    7.273  7.35000  7.427
# Western Europe                   6.937  7.37800  7.587
# Latin America and Caribbean      6.149  6.64600  7.226
# Eastern Asia                     5.729  5.98625  6.298
# Middle East and Northern Africa  5.262  6.32400  7.278

# %%
df_ANZ = df[df['Region'] == 'Australia and New Zealand']
df_NA = df[df['Region'] == 'North America']
df_WE = df[df['Region'] == 'Western Europe']
df_LAC = df[df['Region'] == 'Latin America and Caribbean']
df_EA = df[df['Region'] == 'Eastern Asia']
df_MENA=df[df['Region'] == 'Middle East and North Africa']

# %%
len(df_ANZ[df_ANZ['Happiness Score'] > 6])
# Out:
# 2

# %%
print("There are {} countries in Australia and New Zealand that have a happiness score above 6.0 ".format(len(df_ANZ[df_ANZ['Happiness Score'] > 6])))
# Out:
# There are 2 countries in Australia and New Zealand that have a happiness score above 6.0

# %%
len(df_NA[df_NA['Happiness Score'] > 6])
# Out:
# 2

# %%
print("There are {} countries in North America that have a happiness score above 6.0 ".format(len(df_NA[df_NA['Happiness Score'] > 6])))
# Out:
# There are 2 countries in North America that have a happiness score above 6.0

# %%
len(df_WE[df_WE['Happiness Score'] > 6])
# Out:
# 16

# %%
print("There is {} country in Western Europe that has a happiness score above 6.0 ".format(len(df_WE[df_WE['Happiness Score'] > 6])))
# Out:
# There is 16 country in Western Europe that has a happiness score above 6.0

# %%
len(df_LAC[df_LAC['Happiness Score'] > 6])
# Out:
# 13

# %%
print("There are {} countries in the Latin America and Caribbean that have a happiness score above 6.0 ".format(len(df_LAC[df_LAC['Happiness Score'] > 6])))
# Out:
# There are 13 countries in the Latin America and Caribbean that have a happiness score above 6.0

# %%
len(df_EA[df_EA['Happiness Score'] > 6])
# Out:
# 1

# %%
print("There are {} countries in the Eastern Asia that have a happiness score above 6.0 ".format(len(df_EA[df_EA['Happiness Score'] > 6])))
# Out:
# There are 1 countries in the Eastern Asia that have a happiness score above 6.0

# %%
len(df_MENA[df_MENA['Happiness Score'] > 6])
# Out:
# 0

# %%
print("There are {} countries in the Middle East and Northern Africa that have a happiness score above 6.0 ".format(len(df_MENA[df_MENA['Happiness Score'] > 6])))
# Out:
# There are 0 countries in the Middle East and Northern Africa that have a happiness score above 6.0

# %%
Delta_ANZ = df_ANZ.max(axis=0)['Happiness Score'] - df_NA.min(axis=0)['Happiness Score']
print(Delta_ANZ)
# Out:
# 0.1670000000000007

# %%
Delta_NA = df_NA.max(axis=0)['Happiness Score'] - df_EE.min(axis=0)['Happiness Score']
print(Delta_NA)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-8b39c09423e1> in <module>
# ----> 1 Delta_NA = df_NA.max(axis=0)['Happiness Score'] - df_EE.min(axis=0)['Happiness Score']
#       2 print(Delta_NA)
#
# NameError: name 'df_EE' is not defined

# %%
Delta_WE = df_WE.max(axis=0)['Happiness Score'] - df_WE.min(axis=0)['Happiness Score']
print(Delta_WE)

# %%
Delta_LAC = df_LAC.max(axis=0)['Happiness Score'] - df_A.min(axis=0)['Happiness Score']
print(Delta_LAC)

# %%
Delta_EA= df_EA.max(axis=0)['Happiness Score'] - df_LA.min(axis=0)['Happiness Score']
print(Delta_EA)

# %%
Delta_MENA = df_MENA.max(axis=0)['Happiness Score'] - df_AP.min(axis=0)['Happiness Score']
print(Delta_MENA)

# %%
Deltas = {}

# %%
Deltas["Australia and New Zealand"] = Delta_ANZ
Deltas["North America"] = Delta_NA
Deltas["Western Europe"] = Delta_WE
Deltas["Latin America and Caribbean"] = Delta_LAC
Deltas["Eastern Asia"] = Delta_EA
Deltas["Middle East and Northern Africa	"] = Delta_MENA

# %%
print("The {} region seems to have the largest range of happiness scores".format(max(Deltas, key=Deltas.get)))

# %% [markdown]
# # Bar plot of the Happiness Score¶

# %%
df['Happiness Score'].head(10).plot(xticks=np.arange(9), kind='barh', figsize= (10, 10))
plt.xlabel("Happiness Score")
plt.title('Happiness Score of the top 10 Countries')

# %%
df[[ 'Family','Freedom']].head(10).plot(kind='barh', xticks=np.arange(9), stacked=True, figsize= (10, 10))

plt.xlabel("Happiness Score")
plt.title('Happiness Score of the top 7 Countries')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df_WE[['Freedom', 'Family',]].head(10).plot(kind='barh',xticks=np.arange(9), stacked=True, figsize= (10, 10))

plt.xlabel("Happiness Score")
plt.title('Happiness Score of the top 10 Countries')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# # Histogram of standard error

# %%
WHR['Standard Error'].plot(kind='hist', bins=[ 40, 50, 60, 70, 80, 90, 100], figsize=(10,10))

plt.xlabel("Standard Error in Percent")
plt.title("Distribution of Standard Error")

# %% [markdown]
# # Pairwise Scatter plots

# %%
sns.pairplot(data=df, kind='reg', size = 5,
                  x_vars=['Happiness Score'],
                  y_vars=['Family','Freedom'])

# %%
sns.pairplot(data=df, size = 5, hue='Region',
                  x_vars=['Happiness Score'],
                  y_vars=[ 'Family', 'Freedom',])

# %% [markdown]
# # Correlation

# %%
df.corr(method="pearson", min_periods=20)["Happiness Score"].sort_values(ascending=False)

# %%
df.corr(method="pearson", min_periods=20)["Happiness Score"].abs().sort_values(ascending=False)

# %%
df.corr(method="pearson", min_periods=20)

# %%
corr = df.corr(method = "pearson")

f, ax = plt.subplots(figsize=(10, 10))

sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), 
            cmap=sns.diverging_palette(220, 10, as_cmap=True), square=True, ax=ax)

# %% [markdown]
# # Probabilities

# %%
df[df['Happiness Score'] > 6].shape[0]

# %%
df[(df['Happiness Score'] > 6) & (df['Region'] == 'Western Europe')].shape[0]

# %%
float(len(df[(df['Happiness Score'] > 6) & (df['Region'] == 'Western Europe')]))/float(len(df[df['Happiness Score'] > 6]))

# %%
print("The probability that a randomly selected country with happiness score over 6.0 is form Western Europe is {0:.0%}".format(float(df[(df['Happiness Score'] > 6) & (df['Region'] == 'Western Europe')].shape[0]

)/float(df[df['Happiness Score'] > 6].shape[0])))

# %% [markdown]
# # Matrices

# %%
df.shape

# %%
Australia_NewZealand=[]
North_America=[]
Western_Europe =[]
LatinAmerica_Caribbean=[]
Eastern_Asia = []
MiddleEast_NorthernAfrica = []

# %%
for x in df['Region']:
    if x == 'Australia and New Zealand':
         Australia_NewZealand.append(1)
    else: Australia_NewZealand.append(0)

# %%
for x in df['Region']:
    if x == 'North America':
         North_America.append(1)
    else: North_America.append(0)

# %%
for x in df['Region']:
    if x == 'Western Europe ':
         Western_Europe .append(1)
    else: Western_Europe .append(0)

# %%
for x in df['Region']:
    if x == 'Latin America and Caribbean ':
         LatinAmerica_Caribbean.append(1)
    else: LatinAmerica_Caribbean.append(0)

# %%
for x in df['Region']:
    if x == 'Eastern Asia ':
         Eastern_Asia.append(1)
    else: Eastern_Asia.append(0)

# %%
for x in df['Region']:
    if x == 'Middle East and Northern Africa ':
         MiddleEast_NorthernAfrica.append(1)
    else: MiddleEast_NorthernAfrica.append(0)

# %%
Matrix = pd.DataFrame(index=df.index)

# %%
Matrix['Australia and New Zealand'] = Australia_NewZealand
Matrix['North America'] = North_America
Matrix['Western Europe'] = Western_Europe
Matrix['Latin America and CaribbeanEastern Asia '] = LatinAmerica_Caribbean
Matrix['Eastern Asia '] =  Eastern_Asia
Matrix['Middle East and Northern Africa'] = MiddleEast_NorthernAfrica

# %%
Matrix.head(20)
# Out:
#                       Australia and New Zealand  North America  \
# Country
# Switzerland                                   0              0
# Iceland                                       0              0
# Denmark                                       0              0
# Norway                                        0              0
# Canada                                        0              1
# Finland                                       0              0
# Netherlands                                   0              0
# Sweden                                        0              0
# New Zealand                                   0              0
# Australia                                     0              0
# Israel                                        0              0
# Costa Rica                                    0              0
# Austria                                       0              0
# Mexico                                        0              0
# ...
